# %% [markdown]
# ### 1. Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
import numpy as np

# %% [markdown]
# ### 2. Load Data

# %%
df = pd.read_csv('../data/processed/fake_news_combined.csv')
df.head(5)
# Out:
#                                                title  \
# 0  Trump to keep Manhattan federal prosecutor Bha...
# 1  Democratic Senator Wyden says he will vote for...
# 2  U.N. aid chief appeals for full lifting of Yem...
# 3  Trump returns to hardline position on illegal ...
# 4  Syrian opposition must accept it has not won t...
#
#                                                 text  label
# 0  NEW YORK (Reuters) - Preet Bharara, the top fe...      1
# 1  WASHINGTON (Reuters) - Democratic U.S. Senator...      1
# 2  GENEVA (Reuters) - The United Nations appealed...      1
# 3  PHOENIX (Reuters) - Republican presidential no...      1
# 4  GENEVA (Reuters) - Syria s opposition must acc...      1

# %% [markdown]
# ### 3. Basic Info

# %%
sns.countplot(x='label', data=df)
plt.title("Class Distribution (Fake vs Real)")
plt.xlabel("Label")
plt.ylabel("Count")
plt.show()

# %%
# 5. Text Length Analysis
df['text_length'] = df['text'].apply(lambda x: len(str(x).split()))
sns.histplot(data=df, x='text_length', hue='label', bins=50, kde=True)
plt.title("Distribution of Article Length by Label")
plt.show()

# %%
# 7. Check Duplicates
print("Total duplicate rows:", df.duplicated().sum())
# Out:
# Total duplicate rows: 6259

# %%
# 8. Remove Duplicates
df.drop_duplicates(inplace=True)

# %%
# save cleaned data
df.to_csv("../data/processed/fake_news_combined_cleaned.csv", index=False)
